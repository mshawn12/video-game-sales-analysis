# %% [markdown]
# # Video Game Sales Analysis

# %%
# Import dependencies
import pandas as pd
import numpy as np
pd.set_option('max_colwidth',400)

# %% [markdown]
# ### Video Game Information | Cleaning

# %%
# Read video game data into a Pandas DataFrame

video_game_info_df = pd.read_excel('resources/video-game-info.xlsx')
video_game_info_df.head()
# Out:
#    UNIQUE ID                     Name  Year_of_Release         Genre  \
# 0          1  .hack//Infection Part 1             2002  Role-Playing
# 1          2   .hack//Mutation Part 2             2002  Role-Playing
# 2          3   .hack//Outbreak Part 3             2002  Role-Playing
# 3          4              [Prototype]             2009        Action
# 4          5              [Prototype]             2009        Action
#
#     Publisher              Developer Rating
# 0       Atari          CyberConnect2      T
# 1       Atari          CyberConnect2      T
# 2       Atari          CyberConnect2      T
# 3  Activision  Radical Entertainment      M
# 4  Activision  Radical Entertainment      M

# %%
video_game_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6894 entries, 0 to 6893
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UNIQUE ID        6894 non-null   int64
#  1   Name             6894 non-null   object
#  2   Year_of_Release  6894 non-null   int64
#  3   Genre            6894 non-null   object
#  4   Publisher        6893 non-null   object
#  5   Developer        6890 non-null   object
#  6   Rating           6826 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 377.1+ KB

# %%
# Renaming columns for SQL compatibility 
video_game_info_df = video_game_info_df.rename(columns={
    'UNIQUE ID': 'uniqueid',
    'Name': 'name',
    'Year_of_Release': 'yearreleased',
    'Genre': 'genre',
    'Publisher': 'publisher',
    'Developer': 'developer',
    'Rating': 'rating'
})
video_game_info_df.head()
# Out:
#    uniqueid                     name  yearreleased         genre   publisher  \
# 0         1  .hack//Infection Part 1          2002  Role-Playing       Atari
# 1         2   .hack//Mutation Part 2          2002  Role-Playing       Atari
# 2         3   .hack//Outbreak Part 3          2002  Role-Playing       Atari
# 3         4              [Prototype]          2009        Action  Activision
# 4         5              [Prototype]          2009        Action  Activision
#
#                developer rating
# 0          CyberConnect2      T
# 1          CyberConnect2      T
# 2          CyberConnect2      T
# 3  Radical Entertainment      M
# 4  Radical Entertainment      M

# %% [markdown]
# ### Video Game Sales | Cleaning

# %%
# Read video game sales into a Pandas DataFrame

video_game_sales_df = pd.read_excel('resources/video-game-sales.xlsx')
video_game_sales_df.head()
# Out:
#    UNIQUE ID                     Name  NA_Sales  EU_Sales  JP_Sales  \
# 0          1  .hack//Infection Part 1      0.49      0.38      0.26
# 1          2   .hack//Mutation Part 2      0.23      0.18      0.20
# 2          3   .hack//Outbreak Part 3      0.14      0.11      0.17
# 3          4              [Prototype]      0.84      0.35      0.00
# 4          5              [Prototype]      0.65      0.40      0.00
#
#    Other_Sales  Global_Sales
# 0         0.13          1.27
# 1         0.06          0.68
# 2         0.04          0.46
# 3         0.12          1.31
# 4         0.19          1.24

# %%
video_game_sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6894 entries, 0 to 6893
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   UNIQUE ID     6894 non-null   int64
#  1   Name          6894 non-null   object
#  2   NA_Sales      6894 non-null   float64
#  3   EU_Sales      6894 non-null   float64
#  4   JP_Sales      6894 non-null   float64
#  5   Other_Sales   6894 non-null   float64
#  6   Global_Sales  6894 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 377.1+ KB

# %%
# Renaming columns for SQL compatibility 
video_game_sales_df = video_game_sales_df.rename(columns={
    'UNIQUE ID': 'uniqueid',
    'Name': 'name',
    'NA_Sales': 'nasales',
    'EU_Sales': 'eusales',
    'JP_Sales': 'jpsales',
    'Other_Sales': 'othersales',
    'Global_Sales': 'globalsales'
})
video_game_sales_df.head()
# Out:
#    uniqueid                     name  nasales  eusales  jpsales  othersales  \
# 0         1  .hack//Infection Part 1     0.49     0.38     0.26        0.13
# 1         2   .hack//Mutation Part 2     0.23     0.18     0.20        0.06
# 2         3   .hack//Outbreak Part 3     0.14     0.11     0.17        0.04
# 3         4              [Prototype]     0.84     0.35     0.00        0.12
# 4         5              [Prototype]     0.65     0.40     0.00        0.19
#
#    globalsales
# 0         1.27
# 1         0.68
# 2         0.46
# 3         1.31
# 4         1.24

# %% [markdown]
# ### Video Game User & Critic Scores || Cleaning

# %%
# Read video game user and critic scores into a Pandas DataFrame

video_game_scores_df = pd.read_excel('resources/video-game-scores.xlsx')
video_game_scores_df.head()
# Out:
#    UNIQUE ID                     Name  Critic_Score  Critic_Count  User_Score  \
# 0          1  .hack//Infection Part 1            75            35         8.5
# 1          2   .hack//Mutation Part 2            76            24         8.9
# 2          3   .hack//Outbreak Part 3            70            23         8.7
# 3          4              [Prototype]            78            83         7.8
# 4          5              [Prototype]            79            53         7.7
#
#    User_Count
# 0          60
# 1          81
# 2          19
# 3         356
# 4         308

# %%
video_game_scores_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6894 entries, 0 to 6893
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   UNIQUE ID     6894 non-null   int64
#  1   Name          6894 non-null   object
#  2   Critic_Score  6894 non-null   int64
#  3   Critic_Count  6894 non-null   int64
#  4   User_Score    6894 non-null   float64
#  5   User_Count    6894 non-null   int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 323.3+ KB

# %%
# Renaming columns for SQL compatibility 
video_game_scores_df = video_game_scores_df.rename(columns={
    'UNIQUE ID': 'uniqueid',
    'Name': 'name',
    'Critic_Score': 'criticscore',
    'Critic_Count': 'criticcount',
    'User_Score': 'userscore',
    'User_Count': 'usercount'
})
video_game_scores_df.head()
# Out:
#    uniqueid                     name  criticscore  criticcount  userscore  \
# 0         1  .hack//Infection Part 1           75           35        8.5
# 1         2   .hack//Mutation Part 2           76           24        8.9
# 2         3   .hack//Outbreak Part 3           70           23        8.7
# 3         4              [Prototype]           78           83        7.8
# 4         5              [Prototype]           79           53        7.7
#
#    usercount
# 0         60
# 1         81
# 2         19
# 3        356
# 4        308

# %% [markdown]
# ### Merging (3) datasets

# %%
# Merging the Video Game Info, Video Game Sales, and Video Game Scores DataFrames on Unique ID
video_game_merged_df = video_game_info_df.merge(video_game_sales_df,on='uniqueid',how='left').merge(video_game_scores_df,on='uniqueid',how='left')
video_game_merged_df
# Out:
#       uniqueid                      name_x  yearreleased         genre  \
# 0            1     .hack//Infection Part 1          2002  Role-Playing
# 1            2      .hack//Mutation Part 2          2002  Role-Playing
# 2            3      .hack//Outbreak Part 3          2002  Role-Playing
# 3            4                 [Prototype]          2009        Action
# 4            5                 [Prototype]          2009        Action
# ...        ...                         ...           ...           ...
# 6889      6890                        Zubo          2008          Misc
# 6890      6891               Zumba Fitness          2010        Sports
# 6891      6892  Zumba Fitness: World Party          2013          Misc
# 6892      6893          Zumba Fitness Core          2012          Misc
# 6893      6894          Zumba Fitness Rush          2012        Sports
#
#                   publisher                 developer rating  \
# 0                     Atari             CyberConnect2      T
# 1                     Atari             CyberConnect2      T
# 2                     Atari             CyberConnect2      T
# 3                Activision     Radical Entertainment      M
# 4                Activision     Radical Entertainment      M
# ...                     ...                       ...    ...
# 6889        Electronic Arts           EA Bright Light   E10+
# 6890              505 Games  Pipeworks Software, Inc.      E
# 6891  Majesco Entertainment                  Zoe Mode      E
# 6892              505 Games                  Zoe Mode   E10+
# 6893              505 Games    Majesco Games, Majesco   E10+
#
#                           name_y  nasales  eusales  jpsales  othersales  \
# 0        .hack//Infection Part 1     0.49     0.38     0.26        0.13
# 1         .hack//Mutation Part 2     0.23     0.18     0.20        0.06
# 2         .hack//Outbreak Part 3     0.14     0.11     0.17        0.04
# 3                    [Prototype]     0.84     0.35     0.00        0.12
# 4                    [Prototype]     0.65     0.40     0.00        0.19
# ...                          ...      ...      ...      ...         ...
# 6889                        Zubo     0.08     0.02     0.00        0.01
# 6890               Zumba Fitness     1.74     0.45     0.00        0.18
# 6891  Zumba Fitness: World Party     0.17     0.05     0.00        0.02
# 6892          Zumba Fitness Core     0.00     0.05     0.00        0.00
# 6893          Zumba Fitness Rush     0.00     0.16     0.00        0.02
#
#       globalsales                        name  criticscore  criticcount  \
# 0            1.27     .hack//Infection Part 1           75           35
# 1            0.68      .hack//Mutation Part 2           76           24
# 2            0.46      .hack//Outbreak Part 3           70           23
# 3            1.31                 [Prototype]           78           83
# 4            1.24                 [Prototype]           79           53
# ...           ...                         ...          ...          ...
# 6889         0.11                        Zubo           75           19
# 6890         2.37               Zumba Fitness           42           10
# 6891         0.24  Zumba Fitness: World Party           73            5
# 6892         0.05          Zumba Fitness Core           77            6
# 6893         0.18          Zumba Fitness Rush           73            7
#
#       userscore  usercount
# 0           8.5         60
# 1           8.9         81
# 2           8.7         19
# 3           7.8        356
# 4           7.7        308
# ...         ...        ...
# 6889        7.6         75
# 6890        5.5         16
# 6891        6.2         40
# 6892        6.7          6
# 6893        6.2          5
#
# [6894 rows x 18 columns]

# %%
# Drop unwanted columns
video_game_cleaned = video_game_merged_df.drop(['name_x','name_y'],axis=1)
video_game_cleaned
# Out:
#       uniqueid  yearreleased         genre              publisher  \
# 0            1          2002  Role-Playing                  Atari
# 1            2          2002  Role-Playing                  Atari
# 2            3          2002  Role-Playing                  Atari
# 3            4          2009        Action             Activision
# 4            5          2009        Action             Activision
# ...        ...           ...           ...                    ...
# 6889      6890          2008          Misc        Electronic Arts
# 6890      6891          2010        Sports              505 Games
# 6891      6892          2013          Misc  Majesco Entertainment
# 6892      6893          2012          Misc              505 Games
# 6893      6894          2012        Sports              505 Games
#
#                      developer rating  nasales  eusales  jpsales  othersales  \
# 0                CyberConnect2      T     0.49     0.38     0.26        0.13
# 1                CyberConnect2      T     0.23     0.18     0.20        0.06
# 2                CyberConnect2      T     0.14     0.11     0.17        0.04
# 3        Radical Entertainment      M     0.84     0.35     0.00        0.12
# 4        Radical Entertainment      M     0.65     0.40     0.00        0.19
# ...                        ...    ...      ...      ...      ...         ...
# 6889           EA Bright Light   E10+     0.08     0.02     0.00        0.01
# 6890  Pipeworks Software, Inc.      E     1.74     0.45     0.00        0.18
# 6891                  Zoe Mode      E     0.17     0.05     0.00        0.02
# 6892                  Zoe Mode   E10+     0.00     0.05     0.00        0.00
# 6893    Majesco Games, Majesco   E10+     0.00     0.16     0.00        0.02
#
#       globalsales                        name  criticscore  criticcount  \
# 0            1.27     .hack//Infection Part 1           75           35
# 1            0.68      .hack//Mutation Part 2           76           24
# 2            0.46      .hack//Outbreak Part 3           70           23
# 3            1.31                 [Prototype]           78           83
# 4            1.24                 [Prototype]           79           53
# ...           ...                         ...          ...          ...
# 6889         0.11                        Zubo           75           19
# 6890         2.37               Zumba Fitness           42           10
# 6891         0.24  Zumba Fitness: World Party           73            5
# 6892         0.05          Zumba Fitness Core           77            6
# 6893         0.18          Zumba Fitness Rush           73            7
#
#       userscore  usercount
# 0           8.5         60
# 1           8.9         81
# 2           8.7         19
# 3           7.8        356
# 4           7.7        308
# ...         ...        ...
# 6889        7.6         75
# 6890        5.5         16
# 6891        6.2         40
# 6892        6.7          6
# 6893        6.2          5
#
# [6894 rows x 16 columns]

# %%
video_game_cleaned = video_game_cleaned[['uniqueid','name', 'yearreleased', 'genre', 'publisher', 'developer', 'rating',
       'nasales', 'eusales', 'jpsales', 'othersales', 'globalsales','criticscore', 'criticcount', 'userscore', 'usercount']]
video_game_cleaned
# Out:
#       uniqueid                        name  yearreleased         genre  \
# 0            1     .hack//Infection Part 1          2002  Role-Playing
# 1            2      .hack//Mutation Part 2          2002  Role-Playing
# 2            3      .hack//Outbreak Part 3          2002  Role-Playing
# 3            4                 [Prototype]          2009        Action
# 4            5                 [Prototype]          2009        Action
# ...        ...                         ...           ...           ...
# 6889      6890                        Zubo          2008          Misc
# 6890      6891               Zumba Fitness          2010        Sports
# 6891      6892  Zumba Fitness: World Party          2013          Misc
# 6892      6893          Zumba Fitness Core          2012          Misc
# 6893      6894          Zumba Fitness Rush          2012        Sports
#
#                   publisher                 developer rating  nasales  \
# 0                     Atari             CyberConnect2      T     0.49
# 1                     Atari             CyberConnect2      T     0.23
# 2                     Atari             CyberConnect2      T     0.14
# 3                Activision     Radical Entertainment      M     0.84
# 4                Activision     Radical Entertainment      M     0.65
# ...                     ...                       ...    ...      ...
# 6889        Electronic Arts           EA Bright Light   E10+     0.08
# 6890              505 Games  Pipeworks Software, Inc.      E     1.74
# 6891  Majesco Entertainment                  Zoe Mode      E     0.17
# 6892              505 Games                  Zoe Mode   E10+     0.00
# 6893              505 Games    Majesco Games, Majesco   E10+     0.00
#
#       eusales  jpsales  othersales  globalsales  criticscore  criticcount  \
# 0        0.38     0.26        0.13         1.27           75           35
# 1        0.18     0.20        0.06         0.68           76           24
# 2        0.11     0.17        0.04         0.46           70           23
# 3        0.35     0.00        0.12         1.31           78           83
# 4        0.40     0.00        0.19         1.24           79           53
# ...       ...      ...         ...          ...          ...          ...
# 6889     0.02     0.00        0.01         0.11           75           19
# 6890     0.45     0.00        0.18         2.37           42           10
# 6891     0.05     0.00        0.02         0.24           73            5
# 6892     0.05     0.00        0.00         0.05           77            6
# 6893     0.16     0.00        0.02         0.18           73            7
#
#       userscore  usercount
# 0           8.5         60
# 1           8.9         81
# 2           8.7         19
# 3           7.8        356
# 4           7.7        308
# ...         ...        ...
# 6889        7.6         75
# 6890        5.5         16
# 6891        6.2         40
# 6892        6.7          6
# 6893        6.2          5
#
# [6894 rows x 16 columns]

# %% [markdown]
# ### Exporting Data to CSV

# %%
# Export the clean DataFrame as a CSV file
video_game_cleaned.to_csv('resources/video_game_cleaned.csv',encoding='utf8',index=False)

# %%
# Export individual CSVs
video_game_info_df.to_csv('resources/video_game_info.csv',encoding='utf8',index=False)
video_game_sales_df.to_csv('resources/video_game_sales.csv',encoding='utf8',index=False)
video_game_scores_df.to_csv('resources/video_game_scores.csv',encoding='utf8',index=False)

# %% [markdown]
# ## SQL Setup

# %%
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in /Users/rutgersbootcamp/opt/anaconda3/lib/python3.9/site-packages (2.9.5)

# %%
from sqlalchemy import create_engine

from config import username, password, hostname, port, db

engine = create_engine(f'postgresql+psycopg2://{username}:{password}@{hostname}:{port}/{db}')

# %% [markdown]
# #### SQL Schema for reference
#
# ```sql
# CREATE TABLE video_game_info (
#     uniqueid INT,
#     name VARCHAR,
#     yearreleased INT,
#     genre VARCHAR,
#     publisher VARCHAR,
#     developer VARCHAR,
#     rating VARCHAR,
#     CONSTRAINT pk_video_game_info PRIMARY KEY (
#         uniqueid
#      )
# );
#
# CREATE TABLE video_game_sales (
#     uniqueid INT,
#     name VARCHAR,
#     nasales FLOAT,
#     eusales FLOAT,
#     jpsales FLOAT,
#     othersales FLOAT,
#     globalsales FLOAT,
#     CONSTRAINT pk_video_game_sales PRIMARY KEY (
#         uniqueid
#      )
# );
#
# CREATE TABLE video_game_scores (
#     uniqueid INT,
#     name VARCHAR,
#     criticscore INT,
#     criticcount INT,
#     userscore FLOAT,
#     usercount INT,
#     CONSTRAINT pk_video_game_scores PRIMARY KEY (
#         uniqueid
#      )
# );
#
# ALTER TABLE video_game_sales ADD CONSTRAINT fk_video_game_sales_uniqueid FOREIGN KEY("uniqueid")
# REFERENCES video_game_info ("uniqueid");
#
# ALTER TABLE video_game_scores ADD CONSTRAINT fk_video_game_scores_uniqueid FOREIGN KEY("uniqueid")
# REFERENCES video_game_info ("uniqueid");
#
# SELECT * FROM video_game_scores
# ```
